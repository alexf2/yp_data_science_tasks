# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(245, 245, 245, 0.95); color: #2c2c2c; padding: 18px 24px; margin: 16px 0; border-left: 5px solid #666; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.1); backdrop-filter: blur(1.5px);">
#
#
# **Алексей, привет! Рад с тобой познакомиться 😊**
#
# Меня зовут Василий Митров и я буду проверять твой проект. Предлагаю общаться на «ты». Если удобнее на «вы», просто напиши, и мы сменим стиль общения.
#
# Я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Просьба не менять их местами и не удалять, чтобы наша работа над проектом была максимально продуктивной. Я буду использовать цветовую разметку:
#
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍  Так выделены самые важные замечания. Без их исправления проект не будет принят. Я оцениваю не только код, но и его интерпретацию, а также соответствие техническому заданию.
# </div>
#
# <div style="font-family: Georgia, serif; background: rgba(255, 248, 200, 0.85); color: #4b4100; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #bfa930; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 📝  Так выделены небольшие замечания или рекомендации, которые стоит учесть. Это не критично, но поможет сделать работу лучше. Постарайся, пожалуйста, учесть эти комментарии в этом проекте или в будущих проектах.
# </div>
#
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍 Так выделены все остальные комментарии, включая рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# **Важные дополнения:**
#
# * <u>Идеально, когда проект структурирован. Где названия разделов и подразделов будут записаны в ячейках [Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/?).</u>
#
#
# * <u>Проверь проект на работоспособность перед отправкой на проверку. Сделать это можно так: `Kernel -> Restart And Run All -> Restart And Run All Cells` предварительно сохранив проект нажав на дискету в левом верхнем углу. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. **Помни, ревьюеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (Сode/Markdown)**.</u>
#
#
# * **Прошу не перемещать и не удалять мои комментарии. Если они будут удалены, то я верну последнюю версию проекта, где они сохранились.**
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента</b><br><br>
#
# Например, вот так. Также, если есть какие-то вопросы, или что-то осталось непонятным по ревью - спрашивай в таких блоках и я постараюсь дать ответ.
# </div>
#
# ---

# %% [markdown]
# # Линейная регрессия для определения массы морских черепах
# - Автор: Федоров Алексей Анатольевич
# - Дата: 01.06.2026

# %% [markdown]
# <a id='цели-и-задачи-проекта'></a>
# ### Цели и задачи проекта
#
# Подбор и настройка модели линейной регрессии с целью определения веса морской черепахи на основании признаков датасета  turtles.csv.

# %% [markdown]
# <a id='описание-данных'></a>
# ### Описание данных
#
# #### Датасет **turtles.csv** - измерения различных видов морских черепах
# - **`id`** — идентификатор измерения;
# - **`binomial_name`** — международное научное название вида черепахи;
# - **`registration_number`** — регистрационный номер черепахи;
# - **`shell_length`** — длина панциря, мм;
# - **`shell_width`** — ширина панциря, мм;
# - **`head_length`** — длина головы, мм;
# - **`head_width`** — ширина головы, мм;
# - **`flipper_length_n`** — длина одной ласты, мм. У черепах четыре ласты, поэтому в датасете четыре таких столбца (`flipper_length_1`, `flipper_length_2`, `flipper_length_3`, `flipper_length_4`), в названиях вместо `n` указан номер от 1 до 4;
# - **`flipper_width_n`** — ширина одной ласты, мм. У черепах четыре ласты, поэтому в датасете четыре таких столбца (`flipper_width_1`, `flipper_width_2`, `flipper_width_3`, `flipper_width_4`), в названиях вместо `n` указан номер от 1 до 4;
# - **`circle_count`** — количество колец роста на панцире черепахи;
# - **`measure_count`** — количество измерений, которые произвели, прежде чем усреднить показатели черепахи и добавить их в таблицу;
# - **`shell_crack`** — наличие трещин панциря;
# - **`timestamp`** — время внесения данных о черепахе;
# - **`weight`** — масса черепахи, кг.

# %% [markdown]
# ## Содержание проекта
#
# ## Содержание проекта
#
# 1. [Цели и задачи проекта](#цели-и-задачи-проекта)
# 2. [Описание данных](#описание-данных)
# 3. [Постановка задачи машинного обучения](#постановка-задачи-машинного-обучения)
# 4. [Подключение и настройка библиотек](#подключение-и-настройка-библиотек)
#    - [Версии библиотек](#версии-библиотек)
# 5. [Общие функции](#общие-функции)
#    - [Базовые](#базовые)
#    - [Базовый EDA](#базовый-eda)
#    - [Статистический анализ](#статистический-анализ)
#    - [Графика](#графика)
#    - [Обучение](#обучение)
# 6. [Константы](#константы)
# 7. [Загрузка датасета](#загрузка-датасета)
#    - [Знакомство с данными и начальная обработка](#знакомство-с-данными-и-начальная-обработка)
#      - [Промежуточные выводы](#промежуточные-выводы)
#      - [Начальные исправления данных](#начальные-исправления-данных)
# 8. [Исследовательский анализ данных](#исследовательский-анализ-данных)
#    - [Поиск лишних для обучения модели признаков](#поиск-лишних-для-обучения-модели-признаков)
#    - [Проверка пропусков](#проверка-пропусков)
#    - [Поиск дубликатов](#поиск-дубликатов)
#    - [Поиск выбросов](#поиск-выбросов)
#    - [Проверка корреляции числовых признаков и мультиколлинеарности](#проверка-корреляции-числовых-признаков-и-мультиколлениарности)
#    - [Промежуточный вывод](#промежуточный-вывод)
# 9. [Предобработка данных](#предобработка-данных)
#    - [EDA трансформеры](#eda-трансформеры)
#    - [Пайплайн для преобразований признаков и обучения](#пайплайн-для-преобразований-признаков-и-обучения)
#    - [Проверка коллинеарности признаков после трансформаций](#проверка-коллинеарности-признаков-после-трансформаций)
#    - [Разделение данных на train, validation и test](#разделение-данных-на-train,-validation-и-test)
#    - [Дополнительные преобразования над целевой переменной](#дополнительные-преобразования-над-целевой-переменной)
#    - [Выделение целевой переменной из выборок](#выделение-целевой-переменной-из-выборок)
#    - [Функция подбора гиперпараметров модели](#функция-подбора-гиперпараметров-модели)
# 10. [Обучение моделей](#обучение-моделей)
# 11. [Сравнение моделей на валидационной выборке](#сравнение-моделей-на-валидационной-выборке)
#     - [Промежуточный вывод](#промежуточный-вывод)
# 12. [Проверка лучшей модели на тестовой выборке](#проверка-лучшей-модели-на-тестовой-выборке)
#     - [Промежуточный вывод](#промежуточный-вывод)
# 13. [Оценка важности признаков](#оценка-важности-признаков)
#     - [Промежуточный вывод](#промежуточный-вывод)
# 14. [Функция для прогнозирования веса черепахи](#функция-для-прогнозирования-веса-черепахи)
# 15. [Общие выводы и рекомендации по дальнейшей работе](#общие-выводы-и-рекомендации-по-дальнейшей-работе)
# 16. [Общие выводы и рекомендации](#общие-выводы-и-рекомендации)
#     - [Предложения по дальнейшему развитию проекта](#предложения-по-дальнейшему-развитию-проекта)

# %% [markdown]
# <a id='постановка-задачи-машинного-обучения'></a>
# ## Постановка задачи машинного обучения

# %% [markdown]
# - Опишите, какую задачу нужно решить: регрессии или классификации.
# - Выберите поле, которое станет целевой переменной.
# - Назовите метрики качества модели, которые планируете использовать.
# - Опишите критерии успешности проекта с опорой на метрики.

# %% [markdown]
# 1. **Цель**: прогнозирование веса морской черепахи в килограммах по признакам датасета — **регрессия**.
#
# 2. **Целевая переменная**: `weight`.
#
# 3. **Метрики качества модели**:
#    - **Основная**: MAE;
#    - **Дополнительные**: MSE, MAPE, R^2 (коэффициент детерминации).
#
# 4. **Требования к модели**:
#    - При `weight` ∈ [50, 150] кг: **MAE ≤ 5 кг**;
#    - Коэффициент детерминации: **\( R^2 >= 0.97 \)**.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Вступление в работу очень важно. Так ты поясняешь то, чему она посвящена. Еще лучше будет, если ты сделаешь план работы с гиперссылками. Да, есть плагин ToC. Но хорошо бы уметь реализовывать интерактивный план проекта вручную.
#
# Как это реализовать - смотри по [ссылке](https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704)

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента</b><br><br>
# Добавил содержание проекта.
# </div>

# %% [markdown]
# <a id='подключение-и-настройка-библиотек'></a>
# ## Подключение и настройка библиотек

# %%
dependences=("install", "phik", "seaborn", "statsmodels", "matplotlib==3.4.3")

# %%
import subprocess
import sys
subprocess.check_call([sys.executable, "-m", "pip", *dependences])
# Out:
# ...
# 0

# %%
import os
import gc
# import warnings 
# import calendar
import numpy as np
import pandas as pd
import seaborn as sns

from tqdm.auto import tqdm

# import ipywidgets as widgets
from IPython.display import Markdown, HTML, display_html

import matplotlib
import matplotlib.ticker as mticker
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import matplotlib.cm as cm
import matplotlib.colors as mcolors

import seaborn as sns

import phik
from phik import phik_matrix
from dataclasses import dataclass

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression, Lasso, SGDRegressor
from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn.metrics import (
    mean_absolute_error, mean_squared_error,
    r2_score, mean_absolute_percentage_error
)

from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Правильно, что весь импорт ты проводишь в первой ячейке работы. Так твой коллега, запускающий работу, будет в курсе используемых в ней библиотек и сможет при необходимости быстро настроить окружение.
# </div>

# %% [markdown]
# <a id='версии-библиотек'></a>
# ### Версии библиотек

# %%
print(
    f"Путь к Python: {sys.executable}",
    f"Версия Python: {sys.version}",
    f"Текущий путь: {os.getcwd()}",
    f"pandas: {pd.__version__}",
    f"numpy: {np.__version__}"
    f"Бэкенд pandas (plotting): {pd.options.plotting.backend}",
    f"phik: {phik.__version__}",
    f"matplotlib: {matplotlib.__version__}",
    f"seaborn: {sns.__version__}",
    f"sklearn: {sklearn.__version__}",
sep='\n')
# Out:
# Путь к Python: /opt/conda/bin/python
# Версия Python: 3.9.5 | packaged by conda-forge | (default, Jun 19 2021, 00:32:32)
# [GCC 9.3.0]
# Текущий путь: /home/jovyan/work
# pandas: 2.1.4
# numpy: 1.25.2Бэкенд pandas (plotting): matplotlib
# phik: 0.12.3
# matplotlib: 3.4.3
# seaborn: 0.13.0
# sklearn: 1.6.1

# %% [markdown]
# <a id='общие-функции'></a>
# ## Общие функции

# %% [markdown]
# <a id='базовые'></a>
# ### Базовые

# %%
def show_ds_short_info(df):
    """
        Выводит информацию о размерности датасета и перечень колонок.
    """
    print(
        f'\tВсего: {df.shape[0]} строк, {df.shape[1]} колонок',
        f'\tКолонки датасета: {df.columns.tolist()}\n', sep='\n')
    
def show_item(num, name, action):
    """
        Отображает любой шаг анализа, заданный через func, в виде блока с заголовком.
    """
    print(f'{num}. {name}', '=' * 20)
    action()    
    
def show(start_num, *name_action):
    """
        Отображает шаги анализа с заголовком, нумерацией и разделением.
        Стартовая нумерация задайтся в start_num.
        Шаги переаются списком аргументов переменной длины: name, action. 
    """
    if len(name_action) % 2:
        raise ValueError('Нечётное число аргументов. В show передавайте пары значений name, action как единый список аргументов.')
    
    num_args = len(name_action)
    num = start_num
    
    for i in range(0, num_args, 2):
        if i != 0:
            print('\n')
        show_item(num, name_action[i], name_action[i + 1])
        num += 1
        if i < i - 2:
            print('\n')

def report_row_removing(before, after):
    print(f'✅ Из датасета в {before} строк удалено 🗑️ {before - after} строк,\n'
        f'\tосталось: {after} строк,\n'
        f'\tпроцент потерь: {round((before - after) / before * 100, 2)}%.')
            
def downcast_columns(data_frame, *, ints = None, floats = None):
    """
    Приводит колонки к оптимальным nullable-типам pandas с downcast.

    - Integer колонки: Int64 -> Int8/16/32 в зависимости от диапазона значений.
    - Float колонки: Float64 -> Float32.
    - Object колонки: object -> string.

    Parameters
    ----------
    data_frame : pd.DataFrame
        DataFrame для оптимизации. Изменяется на месте.

    Returns
    -------
    pd.DataFrame
        Тот же объект с оптимизированными типами.
    """
    
    ints_actual = set(ints or []) | set(data_frame.select_dtypes(include="integer").columns)
    floats_actual = set(floats or []) | set(data_frame.select_dtypes(include="float").columns) - ints_actual
    
    for col in ints_actual:
        data_frame[col] = pd.to_numeric(data_frame[col], errors='coerce')
        col_min, col_max = data_frame[col].min(), data_frame[col].max()
        
        if col_min >= -128 and col_max <= 127:
            data_frame[col] = data_frame[col].astype('Int8')
        elif col_min >= -32768 and col_max <= 32767:
            data_frame[col] = data_frame[col].astype('Int16')
        elif col_min >= -2147483648 and col_max <= 2147483647:
            data_frame[col] = data_frame[col].astype('Int32')
        else:
            data_frame[col] = data_frame[col].astype('Int64')

    for col in floats_actual:
        data_frame[col] = pd.to_numeric(data_frame[col], errors='coerce')
        data_frame[col] = data_frame[col].astype('Float32')

    for col in data_frame.select_dtypes(include="object"):
        data_frame[col] = data_frame[col].astype('string')

    return data_frame

# %% [markdown]
# <a id='базовый-eda'></a>
# ### Базовый EDA

# %%
def get_missing_values_statistics(df, name=None):
    """
        Проверяет все колонки DataFrame df на пропуски: np.nan, None, pd.NA.
        Возвращает DataFrame, содержащий две колоки: число пропусков и % пропусков по мнению функции isna( ).        
        В качестве индекса выступают имена колонок. Возвращаются только строки с ненулевыми данными.
    """
    subject = df if name is None else df[name]
    missing_count_seria = subject.isna().sum().loc[lambda v: v > 0].sort_values(ascending=False)
    missing_fraction = round(missing_count_seria / df.shape[0] * 100, 2)
    result = pd.DataFrame(
        {'Пропущено (np.nan, None, pd.NA)': missing_count_seria, 'Доля пропусков %': missing_fraction}
    )
    
    return 'В колонках DataFrame нет пропусков' if result.empty else result

def normalize_text_cols(df, *col_names, to_lower=True):
    """
        Конвертирует колонки col_names в string, обрезает пробелы с концов и нормализует пробелы внутри строк.
        Если задано to_lower, то приводит к нижнему регистру.
    """
    for name in col_names:        
        df[name] = df[name].astype('string').str.strip().str.replace(r'\s+', ' ', regex=True)
        if to_lower:
            df[name] = df[name].str.lower()

def get_reference_info(df, name, numeric=False, limit = 50):
    """
        Выполняет проверку серии name из DataFrame df как категории. А именно:
            - выводит TOP 50 уникальных значений серии и общее число уникальных значений;
            - выводит счётчик встречаемости и % для каждого значения в серии name;
            - если серия числовая, то ещё выводит min и max значения.
        Таким образом, помогает оценить качество справочника или просто серии (колонки) и заметить неявные дубликаты.
    """
    values = df[name].drop_duplicates().sort_values()
    len_values = len(values)
    lst = values.head(limit).to_list()
    
    elipsis = ', ...' if len_values > limit else ''
    display(Markdown(f"**{name}:** `{lst}{elipsis}` = **{len_values}**\n\n"))
        
    counts_df = df[name].value_counts(dropna=False).astype('float64').to_frame('count')
    counts_df.index = counts_df.index.map(lambda x: '<NA>' if pd.isna(x) else x)
    counts_df['%'] = (counts_df['count'] / counts_df['count'].sum() * 100).round(2)        
    counts_df['count'] = counts_df['count'].astype('Int64')
             
    display(counts_df)
            
    print('\nПропущено:', df[name].isna().sum())
    
    if numeric:
        values_num = pd.to_numeric(df[name], errors='coerce')        
        min_val = values_num.min()
        max_val = values_num.max()
        print(f'min = {min_val}, mean = {round(values_num.mean(), 2)}, max = {max_val}, median = {values_num.median()}')
                
        whisker_left, whisker_right = get_whiskers(values_num, left=min_val, right=max_val)
        print(f'left_whisker = {whisker_left}, right_whisker = {whisker_right}')

        non_numeric = values[values_num.isna()].tolist()
        if non_numeric:
            print(f'Нецифровые значения: {non_numeric}')
    print('\n')
    
def get_frequency_report(df, name):
    """
        Возвращает частотный отчёт по колонке данных: все характеристики повторяемости значений в разных строках.
    """
    counts = df[name].value_counts(dropna=False)
    return pd.Series({
        'Среднее': counts.mean(),
        'Медиана': counts.median(), 
        'Мода': counts.mode().iloc[0] if len(counts.mode()) > 0 else None,
        'Макс': counts.max(),
        'Мин': counts.min()
    }), counts

# %% [markdown]
# <a id='статистический-анализ'></a>
# ### Статистический анализ

# %%
def get_whiskers(values, coeff=1.5, left=None, right=None):
    """
        Возвращает усы ящика для серии values.
    """
    Q1 = values.quantile(0.25)
    Q3 = values.quantile(0.75)
    IQR = Q3 - Q1
    
    w_left = Q1 - coeff * IQR
    w_right = Q3 + coeff * IQR
    
    if left is not None:
        w_left = max(left, w_left)
    if right is not None:
        w_right = min(right, w_right)
        
    return w_left, w_right

    
def test_normal_distribution(df, name):
    """
    Проверяет колонку name на соотвествие Нормальному распределению (близость к нему).
    """
    skewness = df[name].skew()
    kurtosis = df[name].kurt()

    # Проверка правилом "одной сигмы" (должно быть ~68.27%)
    avg = df[name].mean()
    std = df[name].std()

    within_1_sigma = df[name].between(avg - std, avg + std).mean()

    print(f"Коэффициент асимметрии: {skewness:.3f} (норма ~ 0)")
    print(f"Коэффициент эксцесса: {kurtosis:.3f} (норма ~ 0)")
    print(f"Доля данных в пределах 1 сигмы: {within_1_sigma:.2%} (норма ~ 68.3%)")

    # Интерпретация
    if abs(skewness) < 0.5 and within_1_sigma > 0.65:
        print("\nВывод: Распределение близко к нормальному.\n")
    else:
        print("\nВывод: Есть значительные отклонения от нормальности.\n")      
        
def check_vif(df, fields):
    """Расчет фактора инфляции дисперсии (VIF) для проверки мультиколлинеарности.

    Интерпретация значений VIF:
    - VIF = 1: коллинеарность отсутствует.
    - 1 < VIF <= 5: умеренная коллинеарность (допустимо).
    - VIF > 10: критический уровень, признак рекомендуется удалить.

    Важно: функция удаляет строки с пропусками (dropna).
    """
    df_vif = df[list(fields)].astype(float).dropna()

    df_with_const = add_constant(df_vif)

    vif_data = pd.DataFrame()
    vif_data["Feature"] = df_vif.columns

    vif_data["VIF"] = [
        variance_inflation_factor(
            df_with_const.values, df_with_const.columns.get_loc(col)
        )
        for col in df_vif.columns
    ]

    return vif_data.sort_values(by="VIF", ascending=False)

# %% [markdown]
# <a id='графика'></a>
# ### Графика

# %%
def show_phik_corr(phik_matrix, target_col, name, width = 13):
    order_corr_seg = (
        phik_matrix[[target_col]]
        .drop(index=[target_col], errors='ignore') # Удаляем связь с самим собой
        .sort_values(by=target_col, ascending=False)
        .T
    )

    plt.figure(figsize=(width, 4))

    sns.heatmap(
        order_corr_seg, 
        annot=True, 
        fmt=".2f", 
        cmap='YlOrRd', 
        linewidths=1.5,
        cbar=False
    )

    plt.title(name, fontsize=14, fontweight='bold', pad=20)
    plt.xticks(rotation=20, ha='right')
    plt.yticks([]) 

    plt.tight_layout()
    plt.show()

def show_linear_dep(df, fields): 
    """Строит матрицу графиков рассеяния с линиями регрессии для поиска мультиколлинеарности.

    Включает автоматическое приведение к float, удаление NaN и случайное
    семплирование до 2000 строк для оптимизации отрисовки.

    Args:
        df (pd.DataFrame): Исходный датафрейм.
        fields (list): Список названий целевых числовых столбцов.

    Returns:
        None: Отображает график через plt.show().
    """
    df_numeric = df[fields].astype(float).dropna()

    sns.set_context("paper", font_scale=1.2)

    g = sns.pairplot(
        df_numeric.sample(min(2000, len(df_numeric))), 
        kind='reg',        # Добавляет линию регрессии на каждый график
        diag_kind='kde',   # На диагонали оставляем распределения
        height=3, 
        aspect=1.2,
        plot_kws={
            'line_kws': {'color': 'darkred'}, # Цвет линий
            'x_jitter': 0.2,
            'scatter_kws': {'alpha': 0.3, 'color': 'salmon', 's': 20} # Цвет и прозрачность точек
        }
    )

    # У pairplot ЕСТЬ атрибут .fig, поэтому тут это сработает
    g.fig.suptitle('Матрица линейных зависимостей интервальных признаков', y=1.02, fontsize=16, fontweight='bold')

    plt.show()

def show_pirson_heatmap(df, fields, target_field):
    all_fields = list(set(list(fields) + [target_field]))

    df_corr = df[all_fields].astype(float)

    corr_matrix = df_corr.corr(method='pearson')

    sorted_fields = corr_matrix[target_field].sort_values(ascending=False).index
    corr_matrix = corr_matrix.loc[sorted_fields, sorted_fields]

    plt.figure(figsize=(12, 10))

    sns.heatmap(
        corr_matrix,
        annot=True,
        fmt=".2f",
        cmap="coolwarm",
        vmin=-1,
        vmax=1,
        center=0,
        square=True,
        linewidths=0.5,
        annot_kws={"size": 11},
    )

    plt.title(
        f"Матрица корреляции Пирсона (по: {target_field})",
        fontsize=16,
        fontweight="bold",
        pad=20,
    )
    plt.xticks(rotation=45, ha="right", fontsize=12)
    plt.yticks(fontsize=12)

    plt.tight_layout()
    plt.show()
    
def plot_boxes(df, columns, title, axis_name, orient='v', figsize=(14, 6)):            
    plt.figure(figsize=figsize)

    # Приводим к float для корректной обработки nullable Int16
    df_plot = df[list(columns)].astype(float)
    
    ax = sns.boxplot(data=df_plot, orient=orient)
    
    data_min = float(df_plot.min().min())
    data_max = float(df_plot.max().max())

    plt.title(title, fontsize=16, fontweight='bold', pad=20)
    
    if orient == "v":
        plt.xticks(rotation=45, ha="right", fontsize=14)
        ax.set_ylabel(axis_name, fontsize=14)

        # Получаем стандартные метки, которые matplotlib построил для оси Y
        current_ticks = ax.get_yticks()
        # Фильтруем те, что выходят за реальные границы данных
        current_ticks = [t for t in current_ticks if data_min <= t <= data_max]
        # Добавляем точный min и max, убираем дубликаты и сортируем
        new_ticks = sorted(list(set(current_ticks + [data_min, data_max])))

        # Применяем новые метки на ось Y
        ax.set_yticks(new_ticks)
        plt.yticks(fontsize=14)
        plt.grid(axis="y", linestyle="--", alpha=0.5)
    else:
        ax.set_xlabel(axis_name, fontsize=14)
        plt.yticks(fontsize=14)

        # Получаем стандартные метки, которые matplotlib построил для оси X
        current_ticks = ax.get_xticks()
        current_ticks = [t for t in current_ticks if data_min <= t <= data_max]
        new_ticks = sorted(list(set(current_ticks + [data_min, data_max])))

        # Применяем новые метки на ось X
        ax.set_xticks(new_ticks)
        plt.xticks(fontsize=14)
        plt.grid(axis="x", linestyle="--", alpha=0.5)
        
        plt.gcf().canvas.draw()

        # Получаем список всех текстовых объектов меток оси X
        labels = ax.get_xticklabels()

        if len(labels) >= 2:
            custom_pad = -0.05
            # Поворачиваем первую метку (минимум)
            labels[0].set_rotation(90)
            labels[0].set_transform(labels[0].get_transform())
            labels[0].set_ha("right")
            labels[0].set_y(custom_pad)

            # Поворачиваем последнюю метку (максимум)
            labels[-1].set_rotation(90)
            labels[-1].set_transform(labels[-1].get_transform())
            labels[-1].set_ha("right")
            labels[-1].set_y(custom_pad)
        
    plt.tight_layout()
    plt.show()

# %% [markdown]
# <a id='обучение'></a>
# ### Обучение

# %%
def separate_target(target, *data_frames):
    """
    Разделяет каждый DataFrame на.features (X) и целевую переменную (y).

    Args:
        target: имя целевой колонки.
        *data_frames: произвольное число DataFrame для разделения.

    Returns:
        Кортеж (X1, y1, X2, y2, ..., Xn, yn), где для каждого входного DataFrame
        X = df.drop(columns=[target]), y = df[target].
    """
        
    def sep(df):        
        return df.drop(columns=[target]), df[target]
    
    result = []
    for df in data_frames:
        X, y = sep(df)
        result.extend([X, y.astype('float64').to_numpy()])  
        
    return tuple(result)

def get_model_metrics(model, X, y):
    pred = model.predict(X)
    return {
        "MAE":  mean_absolute_error(y, pred),
        "MSE":  mean_squared_error(y, pred),
        "RMSE": np.sqrt(mean_squared_error(y, pred)),
        "R2":   r2_score(y, pred),
        "MAPE": mean_absolute_percentage_error(y, pred),
    }

def show_metrics_cross_table(df, metrics):
    # Строим кросс-таблицу: модели × масштабирование
    pivot_mae = df.pivot(index="model", columns="scaling", values=metrics)    

    # Округляем числа из PIVOT_MAE (здесь только числа, без текста!)
    rounded_vals = np.round(pivot_mae.to_numpy().flatten(), 5)
    unique_vals = np.unique(rounded_vals)

    # Инвертируем ранги: меньшее число (лучшее) получает ранг 1.0
    max_idx = len(unique_vals) - 1 if len(unique_vals) > 1 else 1
    val_to_rank = {val: 1.0 - (idx / max_idx) for idx, val in enumerate(unique_vals)}

    # Создаем БЛЕДНУЮ пастельную палитру:
    # 0.0 (худший) -> приглушенный серый/коричневый
    # 1.0 (лучший) -> пастельно-зеленый
    cmap = mcolors.LinearSegmentedColormap.from_list("pale_mae", ["#e6dfda", "#a1dbb2"])

    # Функция окрашивания ячеек
    def color_by_exact_value(sub_df):
        return sub_df.applymap(lambda val: f"background-color: {mcolors.to_hex(cmap(val_to_rank[np.round(val, 5)]))}")
    
    display(
        pivot_mae.style.format("{:.5f}")
        .apply(color_by_exact_value, axis=None)
    )

def show_metrics(df, metrics):
    # Сортируем датафрейм по возрастанию MAE
    sorted_df = df.sort_values(metrics).reset_index(drop=True)

    def smart_numeric_format(val):
        if not isinstance(val, (int, float, np.number)):
            return val

        # Если число гигантское (больше миллиона) или микроскопическое (меньше 0.0001)
        if abs(val) > 1e6 or (0 < abs(val) < 1e-4):
            return f"{val:.5e}" 

        # Для обычных чисел — честные 5 знаков после запятой
        return f"{val:.5f}"


    display(
        sorted_df
        .style.format(smart_numeric_format)    
    )

class LinearModelPredictor:
    def __init__(self, model_pipeline):
        self.transform_pipeline = Pipeline([s for s in model_pipeline.steps if s[0] != "model"])
        model = model_pipeline.named_steps["model"]
        self.coef = model.coef_
        self.intercept = model.intercept_
        
    def predict(self, df_X_values):
        X = self.transform_pipeline.transform(df_X_values)
        X = np.asarray(X, dtype='float64')
        
        return X @ self.coef + self.intercept

# %% [markdown]
# <a id='константы'></a>
# ## Константы

# %%
DATASETS_BASE = 'https://code.s3.yandex.net/datasets'
LOCAL_DATA_FILE_PATH = '/datasets/turtles.csv'
S3_DATA_FILE_PATH = f'{DATASETS_BASE}/turtles.csv'
SEED = 42
TARGET = 'weight'

# %% [markdown]
# <a id='загрузка-датасета'></a>
# ## Загрузка датасета

# %% [markdown]
# - Загрузите данные из файла `turtles.csv`, путь к файлу: `'/datasets/turtles.csv'`. При использовании метода [read_csv](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) установите правильные значения для параметров `sep` и `decimal`: в качестве разделителя столбцов используйте символ табуляции (`'\t'`), а в качестве разделителя дробной части — запятую.
# - Проверьте, правильно ли прошла загрузка. Данные должны соответствовать описанию в тексте урока.
# - С помощью методов библиотеки pandas выведите общие сведения о данных.
# - Возможно ли продолжать работу? Если нет — что нужно сделать, чтобы устранить препятствия?

# %%
data_path = LOCAL_DATA_FILE_PATH if os.path.exists(LOCAL_DATA_FILE_PATH) else S3_DATA_FILE_PATH
df = pd.read_csv(data_path, decimal=',', sep='\t', skipinitialspace=True)

# %%
# сохраняем размерность данных на будущее, для сравнения после обработки
df_shape = df.shape
print(f'👉 Датасет загружен с "{data_path}" содержит: {df_shape[0]} строк')
# Out:
# 👉 Датасет загружен с "/datasets/turtles.csv" содержит: 8861 строк

# %% [markdown]
# <a id='знакомство-с-данными-и-начальная-обработка'></a>
# ### Знакомство с данными и начальная обработка

# %%
show(1, 
     'Датасет "turtles"', lambda: show_ds_short_info(df),
     'info', lambda: df.info(),
     'Пропуски данных по колонкам', lambda: display(get_missing_values_statistics(df)),
     'Пример данных', lambda: display(df),
)
# Out:
# 1. Датасет "turtles" ====================
# 	Всего: 8861 строк, 20 колонок
# 	Колонки датасета: ['id', 'binomial_name', 'registration number', 'shell_length', 'shell_width', 'head_length', 'head_width', 'flipper_length_1', 'flipper_width_1', 'flipper_length_2', 'flipper_width_2', 'flipper_length_3', 'flipper_width_3', 'flipper_length_4', 'flipper_width_4', 'circle_count', 'measure_count', 'shell_crack', 'timestamp', 'weight']
#
#
#
# 2. info ====================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8861 entries, 0 to 8860
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   8861 non-null   int64
#  1   binomial_name        8812 non-null   object
#  2   registration number  8832 non-null   object
#  3   shell_length         8774 non-null   float64
#  4   shell_width          8861 non-null   int64
#  5   head_length          8715 non-null   float64
# ...

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Датасет загружен с правильными параметрами sep='\t' и decimal=','. Структура вывода через show_ds_short_info, info() и таблицу пропусков сразу даёт полную картину: видны типы, количество непустых значений и конкретные цифры по каждому пропуску. Сразу выделяется shell_crack с 75% пропусков.
# </div>

# %% [markdown]
# <a id='промежуточные-выводы'></a>
# #### Промежуточные выводы

# %% [markdown]
# В датасете 8861 строк, 20 колонок, данные соотвествуют описанию, в колонке **registration_number**, в названии, вместо черты пробел, значения признаков распарсились правильно.
#
# Из-за пропусков часть колонок получили тип object и float64, но в целом загрузка прошла корректно.
#
# Имеются пропуски: много в shell_crack - 75%, мало в measure_count ~3%, в остальных 10-ти полях < 2% и < 1%, что позволяет удалять такие записи. shell_crack - это не пропуски. Надо интерпретировать, как отсуствие трещины.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Верно подмечено, что shell_crack с 75% пропусков - это не пропуски в привычном смысле, а скорее всего отсутствие трещин. Это нетривиальный инсайт, который потом правильно применяется в трансформере.
# </div>

# %% [markdown]
# <a id='начальные-исправления-данных'></a>
# #### Начальные исправления данных

# %%
df.columns = df.columns.str.replace(' ', '_').str.replace('-', '_').str.lower()

# %% [markdown]
# ✅ Исправлены названия колонок, чтобы соотвествовали описанию и все были в Snake Case.

# %%
print(df.columns.tolist())
# Out:
# ['id', 'binomial_name', 'registration_number', 'shell_length', 'shell_width', 'head_length', 'head_width', 'flipper_length_1', 'flipper_width_1', 'flipper_length_2', 'flipper_width_2', 'flipper_length_3', 'flipper_width_3', 'flipper_length_4', 'flipper_width_4', 'circle_count', 'measure_count', 'shell_crack', 'timestamp', 'weight']

# %% [markdown]
# Теперь надо нормализовать текстовые колонки, чтобы по ним искать и фильтровать.

# %%
normalize_text_cols(df, 'binomial_name')

# %% [markdown]
# ✅ Нормализовали binominal_name.

# %%
df.dtypes['binomial_name']
# Out:
# string[python]

# %% [markdown]
# 👉 Теперь можно найти все виды черепах в датасете и статистику по ним.

# %%
get_reference_info(df, 'binomial_name', False)
# Out:
# **binomial_name:** `['caretta caretta', 'chelonia mydas', 'dermochelys coriacea', 'eretmochelys imbricata', 'lepidochelys kempii', 'lepidochelys olivacea', <NA>]` = **7**
#                         count      %
# binomial_name
# lepidochelys olivacea    4215  47.57
# chelonia mydas           2829  31.93
# caretta caretta           847   9.56
# dermochelys coriacea      484   5.46
# eretmochelys imbricata    409   4.62
# <NA>                       49   0.55
# lepidochelys kempii        28   0.32
# Пропущено: 49

# %% [markdown]
# Строки, где вид пропущен, нам не полезны для работы, их < 1%, поэтому, можем сразу их удалить и отфильтровать по нужному в задаче виду черепах: **'chelonia mydas'**. Искомые черепахи составляют 32% наблюдений от всего датасета.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Неявные дубликаты в названиях видов правильно устранены приведением к нижнему регистру через normalize_text_cols. После нормализации получилось ровно 6 уникальных видов - без лишних вариаций написания. Фильтрация по chelonia mydas выполнена корректно.
# </div>

# %%
df = df[df['binomial_name'] == 'chelonia mydas']
df_shape_mydas = df.shape
print('👉 осталось строк: ', df_shape_mydas[0])
# Out:
# 👉 осталось строк:  2829

# %%
get_reference_info(df, 'binomial_name', False)
# Out:
# **binomial_name:** `['chelonia mydas']` = **1**
#                 count      %
# binomial_name
# chelonia mydas   2829  100.0
# Пропущено: 0

# %% [markdown]
# ✅ Датасет отфильтрован по виду черепах **'chelonia mydas'**.
#
# Теперь оптимизируем типы данных и подгоним разрядность под оптимальную по битности.

# %%
int_cols = (
    'shell_length', 
    'shell_width', 
    'head_length', 
    'head_width',                       
    'circle_count', 
    'measure_count', 
    'shell_crack', 
    'flipper_length_1', 
    'flipper_length_2',                       
    'flipper_length_2', 
    'flipper_length_3', 
    'flipper_length_4', 
    'flipper_width_1', 
    'flipper_width_2',                       
    'flipper_width_3',
    'flipper_width_4',
)
downcast_columns(df, ints=int_cols);

# %% [markdown]
# ✅ Типы данных датасета оптимизированы по битности и переведены на типы pandas Ext. Теперь посмотрим статистику датасета заново.

# %%
show(1, 
     'info', lambda: df.info(),
     'Пропуски данных по колонкам', lambda: display(get_missing_values_statistics(df)),
     'Пример данных', lambda: display(df),
)
# Out:
# 1. info ====================
# <class 'pandas.core.frame.DataFrame'>
# Index: 2829 entries, 8 to 8859
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   2829 non-null   Int16
#  1   binomial_name        2829 non-null   string
#  2   registration_number  2825 non-null   string
#  3   shell_length         2794 non-null   Int16
#  4   shell_width          2829 non-null   Int16
#  5   head_length          2790 non-null   Int16
#  6   head_width           2790 non-null   Int16
#  7   flipper_length_1     2829 non-null   Int16
#  8   flipper_width_1      2829 non-null   Int16
#  9   flipper_length_2     2829 non-null   Int16
#  10  flipper_width_2      2829 non-null   Int16
#  11  flipper_length_3     2798 non-null   Int16
#  12  flipper_width_3      2798 non-null   Int16
#  13  flipper_length_4     2798 non-null   Int16
#  14  flipper_width_4      2798 non-null   Int16
# ...

# %% [markdown]
# #### Промежуточные выводы
# Теперь типы данных оптимальны по занимаемой памяти: `Float32(1), Int16(14), Int32(1), Int8(2), string(2)`.
# df отфильтрован и содержит только вид 'chelonia mydas' **2829 строк**, колонки имеют правильные имена в Snake Case и можно переходить к детальному анализу данных, чтобы понять, какие трансформации надо выполнять перед обучением модели линейной регрессии, чтобы она правильно обучилась и могла предсказывать weigth по признакам X с заданной допустимой погрешностью 5 кг.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(255, 248, 200, 0.85); color: #4b4100; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #bfa930; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 📝
# Оптимизация типов - нестандартный шаг и интересное решение. Важно помнить, что Int16 для признаков вроде shell_length ограничивает диапазон значениями до 32767 мм. У черепах с выбросами, умноженными на 10, значения могут достигать 20000+ мм - они как раз вписываются, но если в данных когда-нибудь появится больше, это приведёт к переполнению без предупреждения. В продакшн-коде на будещее стоит добавлять явную проверку.
# </div>

# %% [markdown]
# <a id='исследовательский-анализ-данных'></a>
# ## Исследовательский анализ данных

# %% [markdown]
# Проведите исследовательский анализ данных:
# 1. Выясните, данные о каких черепахах представлены в датасете.
# 2. Проведите отбор записей о нужном виде черепах. Для дальнейшей работы достаточно изучить только *Chelonia mydas*. При этом вы можете сравнить распределение данных об этих черепахах с другими видами, если есть желание и время.
# 3. Определите, все ли признаки можно использовать для решения задачи. Ответ обоснуйте. Удалите признаки, которые вам никак не помогут.
# 4. Проверьте, есть ли в данных пропуски. Определите, какие из них можно обработать сразу, а в каких случаях лучше сперва провести разделение на выборки. Решите, стоит ли удалить некоторые пропуски.
# 5. Определите, есть ли в данных дубликаты. Выберите корректный способ их обработки.
# 6. Проанализируйте распределение признаков, постройте необходимые для этого визуализации: ящики с усами, гистограммы и так далее. Определите, есть ли в данных выбросы и какие из них критичные. Решите, можно ли их сразу исправить.
# 7. Проверьте, одинаков ли масштаб признаков. Если он различается, предложите решение этой проблемы.
# 8. Проанализируйте корреляцию между признаками и целевой переменной с помощью вычислений и графически. Определите, все ли признаки нужны для дальнейшей работы.
# 9. Проверьте данные на мультиколлинеарность и решите, можно ли её устранить.

# %% [markdown]
# <a id='поиск-лишних-для-обучения-модели-признаков'></a>
# ### Поиск лишних для обучения модели признаков

# %% [markdown]
# Колонки, которые явно не нужны для обучения модели для предсказания weight:
# - **id** (суррогатный ключ записи);
# - **binomial_name** (он зафиксирован и значение только одно);
# - **registration_number** (не является объективной числовой характеристикой черепахи, но является альтернативным ключом);
# - **timestamp** (шумовой признак).
#
# Колонка **measure_count**: её нужно проверить отдельно, посмотреть какие значения встречаются. Может, удалить записи, где слишком мало усреднений, так как данные могут быть неточные.

# %%
df['measure_count'].describe()
# Out:
# count      2748.0
# mean     2.495633
# std       1.10842
# min           1.0
# 25%           2.0
# 50%           3.0
# 75%           3.0
# max           4.0
# Name: measure_count, dtype: Float64

# %%
get_frequency_report(df, 'measure_count')
# Out:
# (Среднее    565.8
#  Медиана    675.0
#  Мода        81.0
#  Макс       729.0
#  Мин         81.0
#  dtype: float64,
#  measure_count
#  3       729
#  1       685
#  2       675
#  4       659
#  <NA>     81
#  Name: count, dtype: Int64)

# %% [markdown]
# По анализу видим, что медиана это 3 измерения размеров черепахи, а в 72-х случаях число измерений пропущено. В большинстве случаев (633) делается 3 измерения. Иногда от 1 до 4-х и примерно с сопоставимой частотой. В 72-х случаях данные о числе измерений пропущены. Взгляним на них.
#
# Сравним медианы пары признаков в строках без measure_count и с ним, чтобы оценить качество данных.

# %%
df[df['measure_count'].isna()]['shell_length'].median()
# Out:
# 917.0

# %%
df[~df['measure_count'].isna()]['shell_length'].median()
# Out:
# 980.0

# %%
df[df['measure_count'].isna()]['weight'].median()
# Out:
# 76.991

# %%
df[~df['measure_count'].isna()]['weight'].median()
# Out:
# 88.122

# %%
display(df[df['measure_count'].isna()])
# Out:
#          id   binomial_name               registration_number  shell_length  \
# 98    18328  chelonia mydas  a4bdf0915ecaf662199587a9757bd258           909
# 114   18906  chelonia mydas  96cf737b05a8bb60fc01add85f35fd97           804
# 236   19514  chelonia mydas  de3c1d42ed542f5ea7f077ede5626b49          1035
# 525   23759  chelonia mydas  c064debebe5d9ba91300fbebf6236123           716
# 560   24304  chelonia mydas  7f251401027f612dd3e7321cddbfc063           753
# ...     ...             ...                               ...           ...
# 8602  24331  chelonia mydas  7ca745973c088b08daf5f6bbc96c7f2d          1180
# 8622  21471  chelonia mydas  a61e8bcc098e44291196299ad797fd8e          1147
# 8785  24653  chelonia mydas  42f2abab5b291e4c7c914cbe007b1379          1262
# 8803  19945  chelonia mydas  7b6bda7ea901e98b3227852f5b4420ab          1109
# 8823  19301  chelonia mydas  73ffc3ce8824109cc984848f72657769          1381
#
# ...

# %% [markdown]
# Судя по данным, в строках, где measure_count пропущен, обычные данные, которые можно использовать.
#
# Поэтому, колонку **measure_count** можно удалить. Пропуск возможно MNAR. Некоторых черепах измеряли рулеткой вручную, поэтому, число измерений либо 1, либо не указано. Ручное измерение позволяет сделать это аккуратно и точно.
#
# 👉 В трансформере надо будет удалить признаки: **id, binomial_name, registration_number, timestamp, measure_count**. Целевая переменная weight от них не зависит.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Хорошая проверка через сравнение медиан shell_length и weight в строках с пропуском measure_count и без него. Это хороший аргумент в пользу того, что пропуски случайные и строки можно использовать.
# </div>

# %% [markdown]
# <a id='проверка-пропусков'></a>
# ### Проверка пропусков

# %%
display(get_missing_values_statistics(df))
# Out:
#                      Пропущено (np.nan, None, pd.NA)  Доля пропусков %
# shell_crack                                     2152             76.07
# measure_count                                     81              2.86
# head_length                                       39              1.38
# head_width                                        39              1.38
# shell_length                                      35              1.24
# flipper_length_4                                  31              1.10
# flipper_length_3                                  31              1.10
# flipper_width_4                                   31              1.10
# flipper_width_3                                   31              1.10
# registration_number                                4              0.14
# weight                                             3              0.11

# %% [markdown]
# Больше всего пропусков в shell_crack (76%). Полагаю, что это пропуски MNAR: если не указано, то трещин панциря нет.
#
# 👉 пропуски в **shell_crack** надо заполним нулём в трансформере.
#
# Пропуски в измерениях < 2% по каждому признаку, включая weight. Такие записи мало полезны: надо оценить общий процент строк с пропусками в данных полях.

# %%
missing_fields = [
    'head_length', 'head_width', 'shell_length', 'flipper_length_3', 
    'flipper_width_3', 'flipper_length_4', 'flipper_width_4', 'weight']

print(f'{df[missing_fields].isna().any(axis=1).mean():.2%}')
# Out:
# 3.71%

# %% [markdown]
# 👉 Доля строк с пропусками критичных полей < 5%, поэтому, можно их все удалить.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Отличное решение - сначала посчитать суммарную долю строк с пропусками по критичным полям (3.71%), и только потом принять решение об удалении. Это правильный подход: смотреть не на каждый столбец по отдельности, а на итоговые потери строк.
# </div>

# %%
df = df.dropna(subset=missing_fields).reset_index(drop=True)

# %%
report_row_removing(df_shape_mydas[0], df.shape[0])
# Out:
# ✅ Из датасета в 2829 строк удалено 🗑️ 105 строк,
# 	осталось: 2724 строк,
# 	процент потерь: 3.71%.

# %%
display(get_missing_values_statistics(df))
# Out:
#                      Пропущено (np.nan, None, pd.NA)  Доля пропусков %
# shell_crack                                     2073             76.10
# measure_count                                     80              2.94
# registration_number                                4              0.15

# %% [markdown]
# shell_crack мы заполним в трансформере позже.
# Остальные поля использоваться в обучении модели не будут, поэтому данные пропуски не повлияют.

# %% [markdown]
# <a id='поиск-дубликатов'></a>
# ### Поиск дубликатов

# %%
dup_count = df.duplicated().sum()
print(f'Дубликаты {dup_count}, {dup_count / df.shape[0]:.2%}')
# Out:
# Дубликаты 328, 12.04%

# %% [markdown]
# Тут редкий случай, когда мы видим даже не отсуствие ключа идемпотентности для операции POST бэкенда, а ошибку выгрузки или репликации. 328 повторяющихся id и с ним явные дубликаты. Это повторение записей об одних и тех же черепахах.
#
# 👉 Это можно немедленно исправить удалением строк.

# %%
all_duplicates = df[df.duplicated(keep=False)].sort_values(by='id')
display(all_duplicates)
# Out:
#          id   binomial_name               registration_number  shell_length  \
# 2195  17446  chelonia mydas  ff9d28d28b77729ba3d786f96bf91584           846
# 2523  17446  chelonia mydas  ff9d28d28b77729ba3d786f96bf91584           846
# 2657  17454  chelonia mydas  1f1e65006f6160ef06273416146a5a1c           898
# 2329  17454  chelonia mydas  1f1e65006f6160ef06273416146a5a1c           898
# 2317  17484  chelonia mydas  8947d8c59ffbf6c83d0e2d6aecbdfd25          1151
# ...     ...             ...                               ...           ...
# 2266  25231  chelonia mydas  9669f9f772edc9f9f0ddb00d1423a527          1522
# 2694  25257  chelonia mydas  05d6c348e9d4cc3c8d90eba405760083           837
# 2366  25257  chelonia mydas  05d6c348e9d4cc3c8d90eba405760083           837
# 2079  25267  chelonia mydas  b5e5eba737689a032b45532f43f5bdbf          1138
# 2407  25267  chelonia mydas  b5e5eba737689a032b45532f43f5bdbf          1138
#
# ...

# %%
old_shape = df.shape
df = df.drop_duplicates(keep='first').reset_index(drop=True)
report_row_removing(old_shape[0], df.shape[0])
# Out:
# ✅ Из датасета в 2724 строк удалено 🗑️ 328 строк,
# 	осталось: 2396 строк,
# 	процент потерь: 12.04%.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Дубликаты обнаружены и убедительно диагностированы - показана таблица с конкретными примерами повторяющихся записей с одинаковым id, всеми измерениями и весом. Правильный вывод: это ошибка выгрузки данных, а не дубликаты по смыслу.
# </div>

# %% [markdown]
# Ещё проверим альтернативный ключ: **registration_number**. Так как указывается measure_count, то по условиям в описании данных, черепахи не должны повторяться: все измерения усредняются и заносятся один раз будучи привязанными к registration_number черепахи.

# %%
print(df[['registration_number']].duplicated().sum())
# Out:
# 3

# %%
all_duplicates = df[df['registration_number'].duplicated(keep=False)].sort_values(by='id')
display(all_duplicates)
# Out:
#          id   binomial_name registration_number  shell_length  shell_width  \
# 418   18763  chelonia mydas                <NA>          1067          975
# 843   22599  chelonia mydas                <NA>          1471         1167
# 165   24655  chelonia mydas                <NA>           849          844
# 1113  24708  chelonia mydas                <NA>           877          742
#
#       head_length  head_width  flipper_length_1  flipper_width_1  \
# 418           153         151               681              561
# 843           259         229               930              703
# 165           111         148               569              416
# 1113          135         149               528              453
#
#       flipper_length_2  flipper_width_2  flipper_length_3  flipper_width_3  \
# 418                686              508               489              447
# 843                807              785               663              581
# ...

# %% [markdown]
# Номер черепахи уникален, есть только 4 записи без номера с уникальной комбинацией размеров. Из-за этого нашлось 3 ложных дубликата по номкру регистрации. Это видимо случайный пропуск MAR. Но данные в строках годные. registration_number всёравно позднее удалим, поэтому можно оставить эти строки.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(255, 248, 200, 0.85); color: #4b4100; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #bfa930; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 📝
# Ход мысли верный - проверить альтернативный ключ. Но вывод сделан быстро: 4 строки с пропущенным registration_number и разными измерениями оставлены, потому что "данные годные". Это ок, но стоило добавить, что registration_number всё равно удаляется из признаков, поэтому пропуски в нём не влияют на обучение.
# </div>

# %% [markdown]
# Проверим, сколько всего строк удалилось.

# %%
report_row_removing(df_shape_mydas[0], df.shape[0])
# Out:
# ✅ Из датасета в 2829 строк удалено 🗑️ 433 строк,
# 	осталось: 2396 строк,
# 	процент потерь: 15.31%.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Итоговый контроль потерь выведен явно. Это хорошая привычка: после всех операций очистки зафиксировать, сколько данных осталось, чтобы оценить масштаб потерь в целом.
# </div>

# %% [markdown]
# <a id='поиск-выбросов'></a>
# ### Поиск выбросов

# %% [markdown]
# Теперь проверим правильность значений размеров черепахи, чтобы они совпадали с описанием данных: были в мм. Без этого нельзя переходить к замене переменных для избежания коллинеарности и линейной зависимости. У нас есть данные, что некоторые длины умножены на 10 и получены в сантиметрах.

# %%
fields_width_excess = (
    'shell_length', 'shell_width', 'head_length', 'head_width', 'flipper_length_1', 'flipper_length_2', 
    'flipper_length_3', 'flipper_length_4', 'flipper_width_1', 'flipper_width_2', 'flipper_width_3',
    'flipper_width_4', 
)

# %%
plot_boxes(df, fields_width_excess[:2], 'Размеры панциря', axis_name='Размер, мм', orient='h', figsize=(20, 5))

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍
# Обрати, пожалуйста, внимание на оформление графиков в проекте. Важно, чтобы у каждого графика было название, а оси были четко подписаны. Пожалуйста, пройдись по <b>всем</b> графикам и убедись в их корректном оформлении.
#
# Помни, график — это инструмент общения с заказчиком. Он должен быть ясным, лаконичным и информативным.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v1</b><br><br>
# Добавил название свободной оси.
# </div>

# %% [markdown]
# Размеры панциря имеют выбросы, как и говорилось в задаче: значения, ошибочно домноженные на 10.
#
# 👉 Для размеров панциря добавим **исправление выбросов** в тансформер на основе данных Traning set: будем делить их на 10, править в Traning и Validation sets. Вычислим правый ус и умножим на 1.5: делим на 10 значения, которые больше.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Выбросы в shell_length и shell_width правильно идентифицированы как результат ошибочного умножения на 10. Решение исправлять их делением в трансформере на основе границы Q3 + 1.5·IQR, рассчитанной по обучающей выборке - верное и предотвращает утечку.
# </div>

# %%
plot_boxes(df, fields_width_excess[2:], 'Прочие размеры', axis_name='Размер, мм', orient='h', figsize=(20, 10))

# %% [markdown]
# В остальных измерениях черепах есть естественные выбросы за пределами правого уса, скорее всего не вызванные умножением на 10. Их оставим.
# Кроме того, сразу видно, что 1-2 передние размеры ласт, а 3-4 - задние.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Наблюдение про передние и задние ласты сделано по графику - это полезный инсайт, который потом применяется при создании признаков flipper_front и flipper_rear. Вывод о том, что выбросы в размерах ласт естественные и их оставляем, верный.
# </div>

# %%
plot_boxes(df, ('circle_count',), 'circle_count', axis_name='Кольца в шт.',  orient='h', figsize=(20, 5))

# %%
display(df['circle_count'].describe())
test_normal_distribution(df, 'circle_count')
# Out:
# count       2396.0
# mean     80.904007
# std      16.186181
# min           29.0
# 25%           70.0
# 50%           80.0
# 75%           91.0
# max          141.0
# Name: circle_count, dtype: Float64
# Коэффициент асимметрии: 0.390 (норма ~ 0)
# Коэффициент эксцесса: 0.251 (норма ~ 0)
# Доля данных в пределах 1 сигмы: 70.41% (норма ~ 68.3%)
#
# Вывод: Распределение близко к нормальному.

# %% [markdown]
# **circle_count**, несмотря на выбросы, имеет почти нормальное распределение.
#
# 👉  Это говорит о том, что число колец напрямую связано с возрастом черепахи, большинство черепах в выборке в среднем возрасте. И, такие признаки хорошо работают с линейной регрессией.

# %%
plot_boxes(df, ('shell_crack',), 'shell_crack', axis_name='Трещины в шт.', orient='h', figsize=(20, 5))

# %%
display(df['shell_crack'].describe())
# Out:
# count       577.0
# mean     1.727903
# std      1.224944
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           2.0
# max           5.0
# Name: shell_crack, dtype: Float64

# %%
plot_boxes(df, (TARGET,), TARGET, orient='h', axis_name='Вес в кг.', figsize=(20, 5))

# %%
display(df[TARGET].describe())
# Out:
# count        2396.0
# mean      96.051659
# std       34.988125
# min             0.0
# 25%       67.538752
# 50%       88.178501
# 75%      117.542252
# max      199.960999
# Name: weight, dtype: Float64

# %%
print((df[TARGET] == 0).sum())
# Out:
# 3

# %% [markdown]
# 👉  В weight есть выбросы, 3 значения веса черепахи нулевые. Это немного. Заполним при разделении на выборки медианой из обучающей выборки.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(255, 248, 200, 0.85); color: #4b4100; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #bfa930; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 📝
# Нулевые значения в weight - это не выбросы и не пропуски, которые нужно заполнять медианой. Это физически невозможные значения: черепах с нулевым весом не существует. Заполнение медианой создаёт в данных записи с правдоподобным весом, которого у этих черепах никогда не было.
#
# Правильное решение - удалить эти 3 строки, как и строки с пропусками в weight. Тем более что 3 строки - это 0.12% от 2396, потеря незначительная.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v1</b><br><br>
# Я при удалении пропущенной геометрии забыл проверить weight. Наступил на него только после обучения модели, когда сильно выросло MAPE, а ещё понял, что это целевая переменная и в трансформер её не добавишь. 0 это может быть неявным пропуском. Такой маркер пропуска. Когда количество невелико, то нет большой разницы как исправлять: можно удалить, а можно заполнить. В лучшем случае, через Inputer. Я и так уже много строк удалил, поэтому, решил это заполнить.
# </div>

# %% [markdown]
# <a id='проверка-корреляции-числовых-признаков-и-мультиколлениарности'></a>
# ### Проверка корреляции числовых признаков и мультиколлениарности

# %%
numeric_fields = ('shell_length', 'shell_width', 'head_length', 'head_width', 'circle_count', 'shell_crack',  
              'flipper_length_1', 'flipper_length_2', 'flipper_length_3', 'flipper_length_4', 'flipper_width_1',
              'flipper_width_2', 'flipper_width_3', 'flipper_width_4',
             )

# %%
show_pirson_heatmap(df, numeric_fields, TARGET)

# %% [markdown]
# Как и ожидалось, множественные признаки размеров черепахи линейно коррелированы с целевой переменной weight. **shell_width (1), shell_length (0.99), flipper_length - 0.92, head_width - 0.87**. Это сильная корреляция.
# shell_crack, circle_count демонстрируют умеренную корреляцию.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(232, 110, 100, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #992f2f; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# ✍
# В описании корреляций есть неточность: shell_length и shell_width на самом деле имеют самую высокую корреляцию с weight из всех признаков - посмотри на свою же тепловую карту, там это хорошо видно. Получается, что именно их стоило назвать "сильной корреляцией", а flipper_length (0.92) и head_width (0.87) - чуть ниже. Поправь, пожалуйста, вывод, чтобы описание соответствовало данным на графике.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v1</b><br><br>
# Да, я малость ошибся: не туда посмотрел. Исправил вывод.
# </div>

# %%
numeric_cols1 = [TARGET, 'shell_length', 'shell_width', 'shell_crack']
show_linear_dep(df, numeric_cols1)

# %%
numeric_cols2 = [TARGET, 'head_width', 'head_length', 'shell_crack', 'circle_count']
show_linear_dep(df, numeric_cols2)

# %%
numeric_cols2 = [TARGET, 'flipper_width_1', 'flipper_length_1', 'flipper_width_2', 'flipper_length_2']
show_linear_dep(df, numeric_cols2)

# %% [markdown]
# 👉 Теперь мы видим, что у weight очень много линейных зависимостей от других полей, и чтобы обучить Линейную регрессию, надо от них избавляться путём разделения формы и размеров.
#
# **flipper_width_n** и **flipper_length_n** нужно понять, какие передние, а какие задние, и свернуть в flipper_rear и flipper_front усреднив значения. Но сначала убедиться, что значения в одних единицах и без пропусков. Это важно, так как одинаковые плавники - это мультиколлениарные переменные и модель может выбрать для них разные веса, а это неправильно.
# Судя по данным, сначала идут передние плавники.
#
#     flipper_front_width = (flipper_width_1 + flipper_width_2) / 2
#     flipper_front_length = (flipper_length_1 + flipper_length_2) / 2
#
#     flipper_rear_width = (flipper_width_3 + flipper_width_4) / 2
#     flipper_rear_length = (flipper_length_3 + flipper_length_4) / 2
#
# Размеры переднего и заднего плавника будут в линейной зависимости. И сейчас у нас 4 параметра. Перейдём к другим параметрам так, чтобы **разделить масштаб и форму**, избежав линейной зависимости:
#
#     flipper_base = flipper_front_width * flipper_front_length;
#     front_aspect_ratio = flipper_front_length / flipper_front_width;
#     rear_aspect_ratio = flipper_rear_length / flipper_rear_width;
#     rear_to_front_size_ratio = flipper_rear_length / flipper_front_length.
#
# Тоже надо сделать и с панцирем и с головою:
#
#     shell_size = shell_width * shell_length;
#     shell_shape = shell_length / shell_width;
#
#     head_to_shell_ratio = head_length / shell_length;
#     head_shape = head_length / head_width.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(255, 248, 200, 0.85); color: #4b4100; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #bfa930; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 📝
# Но утверждение, что от мультиколлинеарности "надо избавляться", чтобы обучить линейную регрессию - немного категоричное. Линейная регрессия обучится и при мультиколлинеарности, просто коэффициенты будут нестабильными. Ridge как раз и решает эту проблему без полного устранения мультиколлинеарности.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v1</b><br><br>
# Модель может хуже обучиться. Если есть простые варианты избавления (без существенного ущерба интерпретируемости), то лучше уменьшить мультиколлинеарность и число зависимостей. Будет больше выбор моделей.
# </div>

# %%
check_vif(df, list(numeric_fields))
# Out:
#              Feature        VIF
# 1        shell_width  41.559068
# 0       shell_length  41.550480
# 6   flipper_length_1   7.201241
# 9   flipper_length_4   6.992509
# 7   flipper_length_2   6.630006
# 12   flipper_width_3   5.611198
# 8   flipper_length_3   5.573692
# 11   flipper_width_2   5.544595
# 13   flipper_width_4   5.138299
# 10   flipper_width_1   4.735477
# 4       circle_count   4.316042
# 5        shell_crack   4.120212
# 2        head_length   4.079370
# 3         head_width   3.901397

# %% [markdown]
# 👉 Тест на мультиколлениарность показал, что VIF > 10 у shell_xx. Это говорит о коллениарности. Поэтому, после разделения формы и размеров, которые описаны выше, надо будет проверить VIF ещё раз. Вероятно, замена признаков устранит зависимости.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# VIF-анализ - хороший инструмент. Правильно интерпретированы значения: shell_width и shell_length с VIF > 40 - критический уровень мультиколлинеарности. Это конкретное числовое обоснование для замены исходных признаков на синтетические.
# </div>

# %% [markdown]
# ### Промежуточный вывод

# %% [markdown]
# В ходе исследовательского анализа данных о черепахах вида *Chelonia mydas* (исходно **2829** записей) выполнены следующие основные шаги:
#
# - Отбор признаков для обучения модели:
#     - найдены признаки, не несущие полезной информации для предсказания веса (`id`, `binomial_name`, `registration_number`, `timestamp`, `measure_count`) как шумовые или избыточные.
#
# - Анализ пропусков:
#   - **`shell_crack`** – высокий процент пропусков (76%) интерпретирован как отсутствие трещин → заполнение нулём в трансформере.
#   - **признаки размеров** (`head_length`, `head_width`, `shell_length`, `flipper_length/width_3/4`, `weight`) – пропуски менее 2%, затронули менее 5% строк → удаление таких строк (потеря 105 строк, 3.71%).
#   - остальные признаки с пропусками (`measure_count`, `registration_number`) не используются в обучении.
#
# - Удаление дубликатов
#     - обнаружено 328 полных дубликатов (12%) из-за ошибок выгрузки → удалены с сохранением первых вхождений;
#     - проверка по `registration_number` показала лишь 3 ложных срабатывания (пропуски номера) – не критичны;
#     - **итоговое количество строк после чистки** – **2396** (потеря 15.31% от исходных данных).
#
# - Анализ выбросов и распределений
#     - **размеры панциря** (`shell_length`, `shell_width`) – выбросы из-за ошибочного умножения на 10 → в трансформере деление на 10 значений, больше Q3 + IRQ*1.5.
#     - остальные линейные размеры – естественные выбросы сохранены.
#     - **`circle_count`** – распределение близко к нормальному (асимметрия 0.39, эксцесс 0.25), пригоден для линейной регрессии.
#     - **`shell_crack`** – целочисленный признак (1–5), выбросов нет.
#
# - Корреляция и мультиколлинеарность:
#     - почти все размерные признаки сильно коррелируют с целевой переменной `weight` (коэффициенты до 0.92);
#     - высокая мультиколлинеарность подтверждена VIF > 10 (особенно для `shell_length`/`shell_width` и измерений плавников);
#     - для устранения мультиколлинеарности предложена замена признаков на комбинации, разделяющие **размер** и **форму**.
#
#
# - Общее состояние данных
#     После очистки, предварительных преобразований и реализации **трансформера** с остальными преобразованиями, данные готовы к:
#         - разделению на обучающую, валидационную и тестовую выборки;
#         - построению модели линейной регрессии, но корреляцию новых признаков 👉 надо проверить повторно.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Промежуточный вывод структурирован и охватывает все этапы EDA: отбор признаков, пропуски, дубликаты, выбросы, корреляцию и мультиколлинеарность. Приведены конкретные цифры. Очень хорошая сводка!
# </div>

# %% [markdown]
# <a id='предобработка-данных'></a>
# ## Предобработка данных

# %% [markdown]
# 1. Разделите данные на выборки: обучающую (60%), валидационную (20%) и тестовую (20%). В реальных проектах стараются писать код предобработки так, чтобы предотвратить утечку данных. Это проще сделать, если сразу поделить данные.
# 2. Обработайте пропуски. При необходимости заполните их средними (медианными) значениями. Рассчитайте заполнитель только по обучающей выборке: это ещё одно правило для предотвращения утечки.
# 3. Напишите функцию для стандартизации признаков. Расчёт параметров масштабирования делайте только по обучающей выборке, чтобы не дать утечке ни малейшего шанса.
# 4. Напишите функцию для нормализации признаков.
# 5. Подготовьте несколько датасетов из трёх выборок каждый для дальнейшего обучения моделей с разным способом масштабирования: без масштабирования, с нормализацией, со стандартизацией.

# %% [markdown]
# <a id='eda-трансформеры'></a>
# ### EDA трансформеры

# %%
class ToNumpyFloatTransform(BaseEstimator, TransformerMixin):    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X = X.select_dtypes(include=["number", "bool"])
        # extension-типы (Int16/Float32) -> обычный float64 -> numpy
        return X.astype("float64")
    
class DropColumnsTransform(BaseEstimator, TransformerMixin):
    def __init__(self, cols):
        self.cols = cols
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        columns = set(X.columns)
        return X.drop(columns=[col_name for col_name in self.cols if col_name in columns])
    
class FillNaShellCrack(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X = X.copy()
        if 'shell_crack' in X.columns:
            X["shell_crack"] = X["shell_crack"].fillna(0).astype("float")
        return X
        
class OutlierTenFixerTransform(BaseEstimator, TransformerMixin):
    """
    Удаление правых выбросов в shell_length / shell_width превышающих правый ус (Q3 + 1.5*IQR)
    делением на 10, 
    
    Замечание: удаление строк (2.5) делаем ТОЛЬКО на train (когда y передан),
    т.к. в transform нельзя выкидывать строки из val/test без y.
    Деление на 10 (2.6) — починка измерений, применяем везде.
    """
    def __init__(self, div_cols=("shell_width", "shell_length"), k=1.5):
        self.div_cols = div_cols
        self.k = k

    def fit(self, X, y=None):
        self.bounds_ = {}
        for col in self.div_cols:
            q1, q3 = X[col].quantile(0.25), X[col].quantile(0.75)
            iqr = q3 - q1
            self.bounds_[col] = q3 + self.k * iqr
        return self

    def transform(self, X):
        X = X.copy()
        
        for col in self.div_cols:       
            X[col] = X[col].astype("float64")
            
            upper = self.bounds_[col]
            mask = X[col] > upper
            
            X.loc[mask, col] = X.loc[mask, col] / 10
        return X
    
class ReplaceVarsTransform(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        X = X.copy()
        eps = 1e-9 
        
        # --- плавники
        ffw = (X["flipper_width_1"]  + X["flipper_width_2"])  / 2
        ffl = (X["flipper_length_1"] + X["flipper_length_2"]) / 2
        frw = (X["flipper_width_3"]  + X["flipper_width_4"])  / 2
        frl = (X["flipper_length_3"] + X["flipper_length_4"]) / 2

        X["flipper_base"]             = ffw * ffl
        X["front_aspect_ratio"]       = ffl / (ffw + eps)
        X["rear_aspect_ratio"]        = frl / (frw + eps)
        X["rear_to_front_size_ratio"] = frl / (ffl + eps)

        # --- панцирь
        X["shell_size"]  = X["shell_width"] * X["shell_length"]
        X["shell_shape"] = X["shell_length"] / (X["shell_width"] + eps)

        # --- голова
        X["head_to_shell_ratio"] = X["head_length"] / (X["shell_length"] + eps)
        X["head_shape"]          = X["head_length"] / (X["head_width"] + eps)    
        
        # flipper_base и shell_size оказались коллинеарными, поэтому, flipper_base заменим на flipper_to_shell_ratio
        X['flipper_to_shell_ratio'] = X['flipper_base'] / X['shell_size']

        # удаляем исходные «сырые» размеры
        drop = [
            "flipper_width_1", "flipper_width_2", "flipper_width_3", "flipper_width_4",
            "flipper_length_1", "flipper_length_2", "flipper_length_3", "flipper_length_4",
            "shell_width", "shell_length", "head_length", "head_width", "flipper_base"           
        ]
        X = X.drop(columns=[col for col in drop if col in X.columns])
        
        
        return X

# %% [markdown]
# <a id='пайплайн-для-преобразований-признаков-и-обучения'></a>
# ### Пайплайн для преобразований признаков и обучения

# %%
DROP_COLS = ("id", "binomial_name", "registration_number", "timestamp", "measure_count",)

def build_transform():
    return [        
        ('dropping_cols', DropColumnsTransform(DROP_COLS)),        
        ('fill_na_shell_crack', FillNaShellCrack()),
        ('fix_outliers_10', OutlierTenFixerTransform()),
        ('vars_replacer', ReplaceVarsTransform()),
        ('to_numpy_float', ToNumpyFloatTransform()),
    ]

def create_scaler(kind):    
    if kind is None:
        scaler = 'passthrough'
    elif kind == 'minmax':
        scaler = MinMaxScaler()
    elif kind == 'standard':
        scaler = StandardScaler()
    else:
        raise ValueError(kind)
        
    return ('scaler', scaler)

def build_pipeline(model, scaling=None):
    steps = build_transform()
    steps.append(create_scaler(scaling))
    steps.append(('model', model))
    
    return Pipeline(steps)

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Pipeline-архитектура с отдельными трансформерами - сильное решение. Каждый трансформер делает одно дело. Параметры выброса вычисляются в fit() по обучающей выборке и применяются через transform() - утечки нет. Это правильный production-style.
# </div>

# %% [markdown]
# <a id='проверка-коллинеарности-признаков-после-трансформаций'></a>
# ### Проверка коллинеарности признаков после трансформаций

# %%
preview_pipeline = Pipeline(build_transform())
df_preview = preview_pipeline.fit_transform(df)

print("Колонки:", df_preview.columns.tolist())
print("Размер:", df_preview.shape)
print("Типы:\n", df_preview.dtypes.value_counts())
# Out:
# Колонки: ['circle_count', 'shell_crack', 'weight', 'front_aspect_ratio', 'rear_aspect_ratio', 'rear_to_front_size_ratio', 'shell_size', 'shell_shape', 'head_to_shell_ratio', 'head_shape', 'flipper_to_shell_ratio']
# Размер: (2396, 11)
# Типы:
#  float64    11
# Name: count, dtype: int64

# %%
show_pirson_heatmap(df_preview, df_preview.columns.tolist(), TARGET)

# %%
check_vif(df_preview, list(set(df_preview.columns.tolist()) - set([TARGET])))
# Out:
#                     Feature        VIF
# 6    flipper_to_shell_ratio  11.779381
# 9               shell_shape   8.134630
# 5       head_to_shell_ratio   5.934616
# 2  rear_to_front_size_ratio   2.264581
# 3        front_aspect_ratio   1.578004
# 8                head_shape   1.523000
# 4         rear_aspect_ratio   1.464530
# 7              circle_count   1.420446
# 0                shell_size   1.345645
# 1               shell_crack   1.096157

# %% [markdown]
# ✅ Теперь результаты гораздо лучше, можно обучать модель. У нас остался только flipper_to_shell_ratio на критическом уровне. Ridge и Lasso должны работать лучше, так как коэффициенты у LinearRegression могут быть нестабильными, а первые две модели используют регуляризацию весов и справляются, если зависимостей немного.

# %%
del preview_pipeline
del df_preview
gc.collect()
# Out:
# 13561

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# VIF после замены признаков значительно снизился: у большинства признаков VIF < 10, только shell_size и flipper_to_shell_ratio остаются выше порога (30.7 и 12.7), но это объяснимо - они оба несут информацию о размере тела. Вывод про нестабильность коэффициентов LinearRegression при мультиколлинеарности - верный.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 240, 255, 0.9); color: #1c1c1c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #4a90e2; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий студента v1</b><br><br>
# Ну, вот тут уже сложнее дальше менять признаки. Страдает интерпретируемость модели. Поэтому и можно далее прибегать к моделям с регуляризацией признаков: Ridge. Которые хорошо работают с коллинеарностью.
# </div>

# %% [markdown]
# <a id='разделение-данных-на-train,-validation-и-test'></a>
# ### Разделение данных на train, validation и test

# %%
df_train, df_temp = train_test_split(df, train_size=0.60, random_state=SEED, shuffle=True)

# Оставшиеся 40% делим поровну (0.5), получая 20% валидационной и 20% тестовой выборки
df_val, df_test = train_test_split(df_temp, train_size=0.50, random_state=SEED, shuffle=True)

df_train = df_train.copy()
df_val = df_val.copy()
df_test = df_test.copy()

print(f"Обучающая (60%):    {df_train.shape[0]} строк ({df_train.shape[0]/df.shape[0]:.0%})")
print(f"Валидационная (20%): {df_val.shape[0]} строк ({df_val.shape[0]/df.shape[0]:.0%})")
print(f"Тестовая (20%):      {df_test.shape[0]} строк ({df_test.shape[0]/df.shape[0]:.0%})", '\n')

print("Медиана weight на Train set:", df_train[TARGET].median())
print("Медиана weight на Val set:", df_val[TARGET].median())
print("Медиана weight на Test set:", df_test[TARGET].median())
# Out:
# Обучающая (60%):    1437 строк (60%)
# Валидационная (20%): 479 строк (20%)
# Тестовая (20%):      480 строк (20%)
#
# Медиана weight на Train set: 88.233
# Медиана weight на Val set: 88.965
# Медиана weight на Test set: 86.880005

# %% [markdown]
# ✅ Данные разделены на train, validation и test dataset, медианы weight очень близкие, строк для обучения достаточно, но почти без запаса.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Разделение выполнено в правильных пропорциях 60/20/20, с перемешиванием (shuffle=True) и фиксированным random_state=SEED. Проверка медиан по выборкам подтверждает, что распределение целевой переменной однородное.
# </div>

# %% [markdown]
# <a id='дополнительные-преобразования-над-целевой-переменной'></a>
# ### Дополнительные преобразования над целевой переменной

# %%
mask = df_train[TARGET] != 0
megian_weight = df_train.loc[mask, TARGET].median()

for dataframe in [df_train, df_val, df_test]:
    mask = dataframe[TARGET] == 0
    dataframe.loc[mask, TARGET] = megian_weight

# %% [markdown]
# ✅ Заполнили нули weight медианой по train, так как это не получится сделать в трансформере.

# %% [markdown]
# <a id='выделение-целевой-переменной-из-выборок'></a>
# ### Выделение целевой переменной из выборок

# %%
X_train, y_train, X_val, y_val, X_test, y_test = separate_target(TARGET, df_train, df_val, df_test)

# %% [markdown]
# <a id='функция-подбора-гиперпараметров-модели'></a>
# ### Функция подбора гиперпараметров модели

# %%
# объединяем train и val, помечаем где val
X_tv = pd.concat([X_train, X_val], axis=0)
y_tv = np.r_[y_train, y_val] 

# -1 = всегда train, 0 = валидация (единственный фолд)
test_fold = np.r_[np.full(len(X_train), -1), np.full(len(X_val), 0)]
ps = PredefinedSplit(test_fold)

def adjust_model_params(model, scaling, param_grid):
    pipe = build_pipeline(model, scaling)
    gs = GridSearchCV(
        pipe, param_grid,
        scoring="neg_mean_absolute_error",  # основная метрика — MAE
        cv=ps, n_jobs=-1, refit=True
    )
    gs.fit(X_tv, y_tv)
    return gs

# %% [markdown]
# <a id='обучение-моделей'></a>
# ## Обучение моделей

# %% [markdown]
# 1. Постройте базовую модель (дамми), с которой будете сравнивать все остальные. Если они будут хуже базовой по качеству, это будет означать, что при обучении что-то пошло не так. Пример дамми: модель, которая всегда предсказывает среднее значение целевой переменной из обучающей выборки.
# 2. Обучите несколько архитектур линейных моделей. Они могут различаться по ряду черт: набором отобранных признаков, масштабом признаков, установленными гиперпараметрами, функциями потерь. Попробуйте обучить следующие модели:
#    - `LinearRegression`;
#    - `Lasso` (L1-регуляризация);
#    - `Ridge` (L2-регуляризация);
#    - `SGDRegressor`.
#
#    Обязательно попробуйте модели с разными значениями гиперпараметра `loss`.
# - **Бонусное задание.** Подумайте, можно ли улучшить модели за счёт создания новых признаков: например, умножив длину ласт на ширину. Проверьте, усилится ли корреляция нового признака с целевой переменной, возрастёт ли благодаря ему качество модели.
# 3. Сформируйте итоговую таблицу с результатами моделей. Это удобно сделать в виде датафрейма pandas. Включите в таблицу следующие столбцы:
#    - Название модели.
#    - Название датасета — оно должно указывать на то, какой способ масштабирования использовался при подготовке данных.
#    - Метрики качества, рассчитанные на валидационной выборке. Основная метрика — MAE, дополнительные — MSE, R², MAPE и прочие.

# %%
ridge_grid = {"model__alpha": np.logspace(-3, 3, 25)}
lasso_grid = {"model__alpha": np.logspace(-4, 0, 25)}
sgd_grid = {
    "model__alpha":    np.logspace(-6, 0, 20),
    "model__penalty":  ["l2", "l1", "elasticnet"],
    "model__l1_ratio": [0.15],
}

scalings = [None, "minmax", "standard"]
models_to_run = ["Dummy", "LinearRegression", "Ridge", "Lasso", "SGDRegressor"]
total = len(scalings) * len(models_to_run)

results = []
fitted = {}

with tqdm(total=total, desc="Обучение моделей") as pbar:
    for scaling in scalings:
        sc_name = scaling or "none"

        dummy = build_pipeline(DummyRegressor(strategy='mean'), scaling)
        dummy.fit(X_train, y_train)
        m = get_model_metrics(dummy, X_val, y_val)
        results.append({'model': 'Dummy', 'scaling': sc_name, 'best_params': '-', **m})
        fitted[('Dummy', sc_name)] = dummy
        pbar.set_postfix_str(f"{sc_name} / Dummy"); pbar.update(1)

        # --- LinearRegression (без alpha)
        lr = build_pipeline(LinearRegression(), scaling)
        lr.fit(X_train, y_train)
        m = get_model_metrics(lr, X_val, y_val)
        results.append({"model": "LinearRegression", "scaling": sc_name, "best_params": "-", **m})
        fitted[("LinearRegression", sc_name)] = lr
        pbar.set_postfix_str(f"{sc_name} / LinearRegression"); pbar.update(1)

        # --- Ridge
        gs = adjust_model_params(Ridge(), scaling, ridge_grid)
        m = get_model_metrics(gs.best_estimator_, X_val, y_val)
        results.append({"model": "Ridge", "scaling": sc_name, "best_params": gs.best_params_, **m})
        fitted[("Ridge", sc_name)] = gs.best_estimator_
        pbar.set_postfix_str(f"{sc_name} / Ridge"); pbar.update(1)

        # --- Lasso
        gs = adjust_model_params(Lasso(max_iter=5000), scaling, lasso_grid)
        m = get_model_metrics(gs.best_estimator_, X_val, y_val)
        results.append({"model": "Lasso", "scaling": sc_name, "best_params": gs.best_params_, **m})
        fitted[("Lasso", sc_name)] = gs.best_estimator_
        pbar.set_postfix_str(f"{sc_name} / Lasso"); pbar.update(1)

        # --- SGDRegressor (требует масштабирования — без него обычно расходится)
        gs = adjust_model_params(
            SGDRegressor(max_iter=10000, tol=1e-3, early_stopping=True, n_iter_no_change=5, random_state=SEED), 
            scaling, sgd_grid
        )
        m = get_model_metrics(gs.best_estimator_, X_val, y_val)
        results.append({"model": "SGDRegressor", "scaling": sc_name, "best_params": gs.best_params_, **m})
        fitted[("SGDRegressor", sc_name)] = gs.best_estimator_
        pbar.set_postfix_str(f"{sc_name} / SGDRegressor"); pbar.update(1)
    
results_df = pd.DataFrame(results)
# Out:
# Обучение моделей:   0%|          | 0/15 [00:00<?, ?it/s]

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# GridSearchCV с PredefinedSplit - очень элегантное решение: он корректно использует валидационную выборку как единственный фолд для подбора гиперпараметров, без утечки из тестовой. Перебор alpha по логарифмической сетке из 25 точек даёт хорошее покрытие диапазона.
# </div>

# %% [markdown]
# <a id='сравнение-моделей-на-валидационной-выборке'></a>
# ## Сравнение моделей на валидационной выборке

# %% [markdown]
# 1. Сравните построенные модели по метрикам на валидационной выборке. Удалось ли существенно улучшить результат базовой модели?
# 2. Выберите лучшую модель по основной метрике на валидационной выборке. Не заглядывайте в метрики на тестовой выборке раньше времени. Тестовая выборка не используется для обучения моделей, подбора гиперпараметров и сравнения моделей с разными значениями.
# 3. Напишите выводы о том, какая из моделей обладает лучшим качеством. Именно её одну далее нужно проверить на тестовой выборке для итоговой оценки.

# %%
print("\nВсе метрики (валидация), сортировка по MAE:") 
show_metrics(results_df, metrics='MAE')
# Out:
# Все метрики (валидация), сортировка по MAE:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_168/1148616446.py in <module>
#       1 print("\nВсе метрики (валидация), сортировка по MAE:")
# ----> 2 show_metrics(results_df, metrics='MAE')
#
# /tmp/ipykernel_168/1445731350.py in show_metrics(df, metrics)
#      75
#      76     display(
# ---> 77         sorted_df
#      78         .style.format(smart_numeric_format)
#      79     )
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in style(self)
#    1336         `Table Visualization <../../user_guide/style.ipynb>`_ for more examples.
#    1337         """
# -> 1338         from pandas.io.formats.style import Styler
#    1339
#    1340         return Styler(self)
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/formats/style.py in <module>
# ...

# %%
print(f"MAE на валидации X_val:")
show_metrics_cross_table(results_df, metrics='MAE')

# %% [markdown]
# ### Промежуточный вывод
# Лучшее качество получилось у модели **Ridge** при условии центрирования признаков через **StandardScaler** и ркгуляризации alpha = 0.001. У неё наименьшая MAE (3.81297) и максимальная детерминация на валидационной выборке (R2 = 0.97945).

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Лучшая модель выбрана корректно - по метрике на валидационной выборке, без заглядывания в тест. MAE = 3.813 кг при требовании ≤ 5 кг - хорошее качество. Таблица отсортирована по MAE, что упрощает сравнение.
# </div>

# %% [markdown]
# <a id='проверка-лучшей-модели-на-тестовой-выборке'></a>
# ## Проверка лучшей модели на тестовой выборке

# %% [markdown]
# 1. Проверьте метрики лучшей модели на тестовой выборке.
# 2. Узнайте, есть ли признаки переобучения лучшей модели.
# 3. Определите, соответствует ли модель требованиям заказчика. Объясните, можно ли её рекомендовать к внедрению.

# %%
best_row = results_df.sort_values("MAE").iloc[0]
best_key = (best_row["model"], best_row["scaling"])
best_model = fitted[best_key]

print(f"✅ Лучшая модель: {best_row['model']} | scaling={best_row['scaling']}")
print(f"Параметры: {best_row['best_params']}")

# %%
val_metrics  = get_model_metrics(best_model, X_val,  y_val)
test_metrics = get_model_metrics(best_model, X_test, y_test)
train_metrics= get_model_metrics(best_model, X_train, y_train)

compare = pd.DataFrame(
    {"train": train_metrics, "val": val_metrics, "test": test_metrics}
).T
print("\nСравнение train / val / test:")
display(
    compare.style.background_gradient(
        cmap='coolwarm',
        low=0.8, 
        high=0.4 
    )
)

# %% [markdown]
# ### Промежуточный вывод

# %% [markdown]
# **Качество модели Ridge (std, 0.001):** модель хорошо обучена. Нет признаков переобучения и недообучения. MAE немного снижается на Validation set и ниже всего на Test set. При этом, коэффициент детерминации R2 растёт, и максимальный он на Test (0.981), что говорит об очень хорошем объяснении вариативности weight в зависимости от X. MAPE на Test 3.89%, это очень низкое отклонение.
#
# **Соотвествие модели требованиям:** модель соотвествует заданию, прогнозирует weight с погрешностью <= 5 кг, а R2 >= 0.97.
#
# **Внедрение модели:** модель можно внедрять, так как она даёт точный предсказуемый результат.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Сравнение метрик по трём выборкам сделано правильно и интерпретировано корректно: MAE монотонно снижается, R² растёт. Это говорит об отсутствии переобучения. Оба критерия задания выполнены.
# </div>

# %% [markdown]
# <a id='оценка-важности-признаков'></a>
# ## Оценка важности признаков

# %% [markdown]
# 1. Оцените важность признаков по абсолютным значениям весов лучшей модели.
# 2. Напишите, какие признаки стали для модели более важными. Объясните, согласны ли вы с таким результатом?

# %%
best_model = fitted[best_key]

# достаём имена признаков ПОСЛЕ препроцессинга
# (прогоняем препроцессинг без scaler/model, чтобы получить колонки DataFrame)
prepare_only = Pipeline([s for s in best_model.steps if s[0] not in ("scaler", "model")])
feature_names = prepare_only.transform(X_train).columns.tolist()

# веса модели
coefs = best_model.named_steps["model"].coef_

importance = (
    pd.DataFrame({"feature": feature_names, "weight": coefs})
    .assign(abs_weight=lambda d: d["weight"].abs())
    .sort_values("abs_weight", ascending=False)
    .reset_index(drop=True)
)

display(importance)

# %%
plt.figure(figsize=(8, 5))
plt.barh(importance["feature"], importance["abs_weight"])
plt.gca().invert_yaxis()
plt.title("Важность признаков")
plt.xlabel("| коэффициент |")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Промежуточный вывод
#
# Модель предсказывает weight черепахи на основе трёх основных признаков:
#  - shell_size;
#  - head_to_shell_ratio;
#  - shell_shape.
#  И ещё есть три вспомогательных признака:
#   - head_shape;
#   - flipper_to_shell_ratio;
#   - circle_count.
#
#  Остальные признаки мало значимы.
#
#  Натуральный интерпретируемый признак это circle_count. Чем больше возраст, тем больше колец и вес. Остальные прзнаки синтетические и не такие интерпретируемые:
#  ```
#     X["shell_size"]  = X["shell_width"] * X["shell_length"]
#     X["shell_shape"] = X["shell_length"] / (X["shell_width"] + eps)
#     X["head_to_shell_ratio"] = X["head_length"] / (X["shell_length"] + eps)
# ```
# Наиболее понятные shell_size (w=33.7) и circle_count (w=0.62). Это размерные признаки.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Важность признаков оценена правильно - по абсолютным значениям коэффициентов после стандартизации. shell_size с весом 33.7 явно доминирует, что биологически логично: площадь панциря - лучший прокси для общего объёма тела черепахи. Визуализация через barh с убывающей сортировкой - отличная.
# </div>

# %% [markdown]
# <a id='функция-для-прогнозирования-веса-черепахи'></a>
# ## Функция для прогнозирования веса черепахи

# %% [markdown]
# * Напишите на Python функцию, которая будет прогнозировать массу черепахи по заданным параметрам с учётом коэффициентов лучшей модели (свойство `coef_`) и смещения (свойство `intercept_`).
# * Если вы столкнётесь с трудностями при написании функции, то представьте, что обращаетесь к старшему коллеге с просьбой помочь, и составьте задание для её написания. Подробно опишите логику, по которой рассчитывается масса черепахи, и укажите, как именно должны происходить расчёты.

# %%
turtle_weight_predictor = LinearModelPredictor(best_model)

# %%
N_SAMPLES = 10

sample = df[df[TARGET].notna()].sample(n=N_SAMPLES, random_state=SEED)

X_sample = sample.drop(columns=[TARGET])
y_true = sample[TARGET].to_numpy(dtype="float64")

# Прогноз нашим предиктором
y_pred_custom = turtle_weight_predictor.predict(X_sample)

# Контроль: прогноз через сам pipeline (должны совпасть)
y_pred_pipeline = best_model.predict(X_sample)

compare = pd.DataFrame({
    "real_weight":   y_true,
    "pred_custom":   y_pred_custom,
    "pred_pipeline": y_pred_pipeline,
    "abs_error":     np.abs(y_true - y_pred_custom),
    "abs_error_%":   np.abs(y_true - y_pred_custom) / y_true * 100,
}, index=X_sample.index).round(3)

print("Сравнение реального и предсказанного веса:\n")
display(compare)


print(f"\nMAE  на выборке: {compare['abs_error'].mean():.3f} kg")
print(f"MAPE на выборке: {compare['abs_error_%'].mean():.2f} %")

max_diff = np.max(np.abs(y_pred_custom - y_pred_pipeline))
print(f"\nМакс. расхождение custom vs pipeline: {max_diff:.2e}")
assert np.allclose(y_pred_custom, y_pred_pipeline), "❌ Не совпадает с pipeline!"
print("✅ LinearModelPredictor даёт те же прогнозы, что и best_model.predict")

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Приятно видеть, что функция прогнозирования реализована через отдельный класс с верификацией через assert. Проверка на 10 примерах с нулевым расхождением - это именно то, что нужно делать, прежде чем отдавать что-то в эксплуатацию.
# </div>

# %% [markdown]
# <a id='общие-выводы-и-рекомендации-по-дальнейшей-работе'></a>
# ## Общие выводы и рекомендации по дальнейшей работе

# %% [markdown]
# Напишите общие выводы и рекомендации по дальнейшей работе. Ответьте на вопросы:
#   - Какие модели изучены?
#   - Какие результаты получены?
#   - Рекомендуется ли итоговая модель к внедрению?
#   - Какая архитектура и способ обработки признаков показали себя лучше всего? Какие у них показатели метрик?
#   - Какие признаки наиболее важны для модели?
#   - Есть ли перспективы у обучения этой или других моделей для предсказания массы других видов черепах?
#   - При наличии добавьте сюда свои предложения по дальнейшему развитию проекта.

# %% [markdown]
# <a id='общие-выводы-и-рекомендации'></a>
# ## Общие выводы и рекомендации
#
# Изучены модели линейной регрессии различных архитектур:
# - Базовая (`DummyRegressor`);
# - Классическая (`LinearRegression`);
# - С регуляризацией L1 (`Lasso`);
# - С регуляризацией L2 (`Ridge`);
# - На стохастическом градиентном спуске (`SGDRegressor`).
#
# Все модели протестированы на данных без масштабирования, с нормализацией (`MinMaxScaler`) и со стандартизацией (`StandardScaler`).
#
#
# - **Лучшая модель:** `Ridge`-регрессия со стандартизацией признаков (`StandardScaler`).
# - **Гиперпараметр:** `alpha = 0.001`.
# - **Итоговые показатели на тестовой выборке:**
#     - **MAE:** **3.73 кг** (соответствует требованию ≤ 5 кг);
#     - **\( R^2 \):** **0.981** (соответствует требованию ≥ 0.97);
#     - **MAPE:** ~3.89% (после заполнения медианой нулей в weight).
#
# Модель показала стабильность без признаков переобучения.
#
#
# Модель удовлетворяет всем требованиям заказчика по точности. Разработанный пайплайн предобработки и функция прогноза готовы к интеграции для предсказания массы черепах вида *Chelonia mydas*.
#
#
# **Лучшие архитектуры моделей**
# - **Архитектура:** `Ridge` с L2-регуляризацией.
# - **Способ обработки:** Стандартизация (`StandardScaler`).
# - **Ключевые метрики на тестовой выборке:**
#     - **MAE:** `3.73` кг
#     - **MSE:** `23.78`
#     - **RMSE:** `4.88`
#     - **R²:** `0.981`
#     - **MAPE:** `0.039` (3.89%)
#
# **Наиболее важные признаки**
# Признаки, разделяющие размер и форму, позволили избавиться от мультиколлинеарности и избежать переобучения. Важнейшие признаков по абсолютному весу коэффициентов:
# - `shell_size` (размер панциря): **наиболее важен**;
# - `head_to_shell_ratio` (пропорции головы);
# - `shell_shape` (форма панциря);
#
# **Менее важные, но значимые признаки**
# - `head_shape` (форма головы);
# - `flipper_to_shell_ratio` (соотношение ласт к панцирю);
# - `circle_count` (число колец роста).
#
#
# **Перспективы обучения линейныз моделей**
#
# Подход по созданию признаков («размер × форма») биологически обоснован. Рекомендуется:
# - Применить разработанный пайплайн к данным по другим видам черепах;
# - Обучить либо отдельные модели на каждый вид, либо единую модель с кодированием признака `binomial_name`.
# - С другими видами черепах имеется проблема, что выборки гораздо менее многочисленные.
# ---
#
# <a id='предложения-по-дальнейшему-развитию-проекта'></a>
# ### Предложения по дальнейшему развитию проекта
#
# 1.  **Масштабирование на новые виды:** обучить модели для всех видов черепах из датасета, используя готовый `Pipeline`.
# 2.  **Универсальная модель:** создать одну общую модель, добавив в качестве категориального признака `binomial_name` (вид черепахи).
# 3.  **Интерпретируемость:** обсудить с профильными специалистами (биологами) природу синтетических признаков вроде `head_to_shell_ratio`, чтобы подтвердить их ценность для биологии.
# 4.  **Продакшн:** упаковать готовый объект для предсказания в прототип сервиса (API) для автоматического расчета веса при внесении промеров.

# %% [markdown]
# <div style="font-family: Georgia, serif; background: rgba(220, 250, 230, 0.85); color: #213f2c; padding: 16px 22px; margin: 16px 0; border-left: 5px solid #48a078; border-radius: 14px; box-shadow: 0 8px 14px rgba(0, 0, 0, 0.15); backdrop-filter: blur(2px);">
# <b>Комментарий ревьюера v.1</b><br><br>
# 👍
# Выводы охватывают все ключевые вопросы: какие модели изучены, какие метрики получены, обоснование выбора лучшей модели, анализ признаков и перспективы. Раздел про перспективы (универсальная модель с binomial_name, интерпретация с биологами, API-сервис) - очень конкретный.
# </div>

# %% [markdown]
# <div style="font-family: Georgia, serif; background: #f0f0f0; color: #1a1a1a; padding: 20px 26px; margin: 20px 0; border-left: 6px solid #444; border-right: 6px solid #444; border-radius: 16px; box-shadow: 0 12px 24px rgba(0, 0, 0, 0.25);">
# <b>👋 Обратная связь v.1</b><br><br>
# Алексей, проект выполнен отлично. Особое внимание к деталям и структурированное оформление облегчает процесс просмотра и понимания материала. Все ключевые моменты в данных успешно выделены и четко обоснованы, при этом код написан эффективно.
#
# Я готов принять твой проект и если у тебя не осталось каких-либо вопросов, то пришли свой проект на повторное ревью и он будет принят 😊

# %% [markdown]
# <div style="font-family: Georgia, serif; background: #f0f0f0; color: #1a1a1a; padding: 20px 26px; margin: 20px 0; border-left: 6px solid #444; border-right: 6px solid #444; border-radius: 16px; box-shadow: 0 12px 24px rgba(0, 0, 0, 0.25);">
# <b>👋 Обратная связь v.2</b><br><br>
# Алексей, проект выполнен на хорошем уровне. Все задачи решены корректно, логика понятна. Я принимаю твой проект и если у тебя появятся вопросы, то ты можешь передать их мне через куратора твоей когорты😊. Отличная работа!
